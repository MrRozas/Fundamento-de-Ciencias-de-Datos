# %% [markdown]
# # Fundamentos de Ciencias de Datos
#
# *Esta tarea tiene dos partes. Una parte en parejas y otra individual. La parte en parejas se encuentra en el archivo **tarea_01.ipynb**. Luego, cada uno de los integrantes de la pareja debe tomar la sección A o la sección B, y cada integrante debe realizar solamente la sección de la tarea que escogió. Este cuaderno de python contiene la realización de la **sección A** de la tarea, parte individual*
#
# ## Tarea 1 (Parte Individual - Sección A)
#
# ### Objetivos
#
# 1. Familiarización con Python en el contexto de Ciencias de Datos
# 2. Manejo de conjuntos de datos utilizando funciones propias de Pandas
#
# ### Metodología
#
# Deberás completar este cuaderno de python, siguiendo las instrucciones contenidas en él. Puedes utilizar contenido que encuentre en internet siempre y cuando lo referencies a través de un comentario. Por ejemplo:
#
# >```Python
# ># código para abrir archivo obtenido desde  https://uniwebsidad.com/libros/algoritmos-python/capitulo-11
# >archivo = open("archivo.txt")
# >```
#
# No olvides poner nombres representativos a tus variables. Caso contrario se verá reflejado en una penalización de tu nota.
#
# ### Conjuntos de Datos
#
# Se le entregan 3 conjuntos de datos: codigos.csv, datos_comunas.csv, presupuesto_2019.csv.
#
# #### codigos.csv
#
#  | columna | descripción |
#  | --- | :---: |
#  | Código Región | **Entero**: Identificador único para cada región. |
#  | Nombre Región | **String**: Nombre de la región. |
#  | Abreviatura Región | **String**: Abreviatura (en letras) o nombre corto de la región.  |
#  | Código Provincia | **Entero**: Identificador único para cada provincia. |
#  | Nombre Provincia | **String**: Nombre de la provincia. |
#  | Código Comuna 2018 | **Entero**: Identificador único para cada comuna. |
#  | Nombre Comuna | **String**: Nombre de la comuna. |
#
#  #### datos_comunas.csv
#
#  | columna | descripción |
#  | --- | :---: |
#  | id | **Entero**: Identificador único para cada comuna. Mismo identificador que en **codigos.csv**. |
#  | metros_plaza | **Entero**: Cantidad de metros de plaza que tiene la comuna. |
#  | metros_parque | **Entero**: Cantidad de metros de parque que tiene la comuna.  |
#  | personas_trabaja | **Entero**: Número de personas que trabaja en la municipalidad de la comuna. |
#
#  #### presupuesto_2019.csv
#
#  | columna | descripción |
#  | --- | :---: |
#  | CODIGO | **Entero**: Identificador único para cada comuna. Mismo identificador que en **codigos.csv**. |
#  | MUNICIPIO | **String**: Nombre de la comuna. |
#  | PRESUPUESTO | **Entero**: Presupuesto destinado a la comuna.  |
#
#  **Observación**: en la columna `PRESUPUESTO`, hay datos que están como "no recepcionados. Eso puede producir que los análisis fallen, por lo que se recomienda limpiar los datos antes.
#
#  #### poblacion.csv
#
#  | columna | descripción |
#  | --- | :---: |
#  | CODIGO | **Entero**: Identificador único para cada comuna. Mismo identificador que en **codigos.csv**. |
#  | MUNICIPIO | **String**: Nombre de la comuna. |
#  | POBLACIÓN | **Entero**: Número de personas que vive en la comuna.  |

# %% [markdown]
# ## Nombre alumno
#
# Por favor, llenar acá con su nombre.
#
# **<Ponga su nombre acá>**

# %% [markdown]
# ## Recomendaciones
#
# Primero, deberías importar en la siguiente celda **TODOS** los módulos de Python necesarios para la correcta ejecución de su tarea.

# %%
#Escriba su código aquí
import pandas as pd

# %% [markdown]
# Luego, deberías guardar en una (o varias) variable(s) TODOS los sets de datos que utilizarás en la tarea.

# %%
#Escriba su código aquí
codigos = pd.read_csv("codigos.csv", sep=';')
datos_comunas = pd.read_csv("datos_comunas.csv")
poblacion = pd.read_csv("poblacion.csv", sep=';')
presupuesto = pd.read_csv("presupuesto_2019.csv", sep=';')

# %% [markdown]
# Utilice las variables previamente guardadas para mostrar parte de la información de todos los conjuntos de datos. Vale decir, si usted creó dos variables, cada una con un conjunto de datos diferente, muestre parte de los dos conjuntos de datos. Esto te ayudará a entender mejor lo que contiene cada fuente de datos.

# %%
#Escriba su código aquí
print("Codigos:")
display(codigos.head())
print("Datos comunas:")
display(datos_comunas.head())
print("Población:")
display(poblacion.head())
print("Presupuesto:")
display(presupuesto.head())
# Out:
# Codigos:
#    Código Región Nombre Región  ... Código Comuna 2018  Nombre Comuna
# 0              1      Tarapacá  ...               1101        Iquique
# 1              1      Tarapacá  ...               1107  Alto Hospicio
# 2              1      Tarapacá  ...               1401   Pozo Almonte
# 3              1      Tarapacá  ...               1402         Camiña
# 4              1      Tarapacá  ...               1403       Colchane
#
# [5 rows x 7 columns]
# Datos comunas:
#      id  metros_plaza  metros_parque  personas_trabaja
# 0  1101       58460.0        94824.0             271.0
# 1  1107      130316.0            0.0              55.0
# 2  1401           NaN            NaN               NaN
# 3  1402        4050.0            0.0               8.0
# 4  1403        2532.0            NaN               NaN
# Población:
#    CODIGO      MUNICIPIO  POBLACIÓN
# 0    1101        IQUIQUE     216514
# 1    1107  ALTO HOSPICIO     124150
# 2    1401   POZO ALMONTE      16683
# 3    1402         CAMIÑA       1345
# 4    1403       COLCHANE       1556
# Presupuesto:
#    CODIGO      MUNICIPIO PRESUPUESTO
# 0    1101        IQUIQUE    59072234
# 1    1107  ALTO HOSPICIO    13984411
# 2    1401   POZO ALMONTE     7613962
# 3    1402         CAMIÑA     1584008
# 4    1403       COLCHANE     2500000

# %% [markdown]
# Además, si necesitas hacer algún pre-procesamiento **COMÚN** a todas sus futuras respuestas, deberías hacerlo en la siguiente celda

# %%
#Escriba su código aquí
datos_comunas = datos_comunas.fillna(0)
poblacion = poblacion.fillna(0)
presupuesto = presupuesto.fillna(0)
codigos = codigos.fillna(0)

# %% [markdown]
# ## Actividad
#
# ### Parte Individual A
# 1. Genera un dataframe ordenado de manera descendente (más alta primero, más baja al final) según la relación $\frac{\text{metros de plaza}}{\text{población}}$. Las columnas que debes mostrar son el nombre de la comuna y la proporción señalada.
# 2. Calcula el presupuesto promedio por región. ¿Cuál es la región que tiene el mayor presupuesto promedio?
# 3. Con base en los datos, responda la siguiente pregunta: revise las 20 comunas con mayor cantidad de población. ¿Cuáles de ellas también son parte de las comunas con más presupuesto? ¿Qué puede comentar de esta situación?
#
# ## Detalles académicos
#
# La nota de cada integrante de la pareja será calculado como $0.5 \cdot \text{Parte Grupal} + 0.5 \cdot \text{Parte Individual} $, donde la Parte Grupal corresponde a las 7 primeras consultas, y la parte individual a la sección respectiva elegida por cada integrante. **La tarea debe ser subida al buzón correspondiente de Webcursos hasta el XX de Agosto hasta las XX:XX horas**.
#
# **Importante**: Recuerde que debe generar el código que responda las preguntas. Por ejemplo para la pregunta 4, debe entregar el código que muestre por pantalla la región con la mayor cantidad de metros de plaza. Si entrega sólo el dataframe ordenado su respuesta **no estará completamente correcta**.

# %% [markdown]
# ## Pregunta 1

# %%
# Escriba su código aquí

df_metrosplaza_poblacion = pd.merge(poblacion, datos_comunas, left_on='CODIGO', right_on='id')

div= df_metrosplaza_poblacion['metros_plaza']/df_metrosplaza_poblacion['POBLACIÓN']
div= div.to_frame()  #Código sacado de https://pandas.pydata.org/docs/reference/api/pandas.Series.to_frame.html
div.columns=['Metros plaza/Población']

df_metrosplaza_poblacion_div = pd.merge(df_metrosplaza_poblacion, div, left_index=True, right_index=True)

df_proporcion = df_metrosplaza_poblacion_div[['MUNICIPIO','Metros plaza/Población']]

print("DataFrame de las comunas ordenadas de mayor a menor en proporción Metros de plaza/Población:")

df_proporcion.sort_values(by='Metros plaza/Población', ascending=False)
# Out:
# DataFrame de las comunas ordenadas de mayor a menor en proporción Metros de plaza/Población:
#          MUNICIPIO  Metros plaza/Población
# 50       RINCONADA             3451.165577
# 252      PRIMAVERA               24.831897
# 245     RÍO IBÁÑEZ               17.716995
# 242      O´HIGGINS               16.903817
# 67   SANTO DOMINGO               16.885927
# ..             ...                     ...
# 247  LAGUNA BLANCA                0.000000
# 248      RÍO VERDE                0.000000
# 52        LA LIGUA                0.000000
# 295           BUIN                0.000000
# 119   SAN CLEMENTE                0.000000
#
# [345 rows x 2 columns]

# %% [markdown]
# ## Pregunta 2

# %%
# Escriba su código aquí
df_pre_reg = pd.merge(presupuesto, codigos, left_on='CODIGO', right_on='Código Comuna 2018')

df_presupuesto_region = df_pre_reg[['Nombre Región','Nombre Comuna', 'PRESUPUESTO']]
df_presupuesto_region['PRESUPUESTO'].convert_dtypes() #Código sacado de https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.convert_dtypes.html
df_presupuesto_region.PRESUPUESTO = pd.to_numeric(df_presupuesto_region.PRESUPUESTO, errors='coerce') #Código sacado de https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html

df_prom_region_presupuesto = df_presupuesto_region.groupby('Nombre Región').mean()

mayor_prom_pre_region = df_prom_region_presupuesto.sort_values(by='PRESUPUESTO', ascending=False)

print("Promedio de presupuesto de regiones ordenadas de mayor a menor:")
display(mayor_prom_pre_region)

print("La región con mayor promedio de presupuesto es la metropolitana")
display(mayor_prom_pre_region[:1])
# Out:
# Promedio de presupuesto de regiones ordenadas de mayor a menor:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                             PRESUPUESTO
# Nombre Región
# Metropolitana de Santiago                  4.341656e+07
# Antofagasta                                2.123443e+07
# Valparaíso                                 1.351591e+07
# Tarapacá                                   1.351320e+07
# Coquimbo                                   1.351013e+07
# Arica y Parinacota                         1.109735e+07
# Biobío                                     9.816258e+06
# Atacama                                    8.323193e+06
# Maule                                      7.770909e+06
# Los Ríos                                   7.492851e+06
# La Araucanía                               6.944642e+06
# Libertador General Bernardo O'Higgins      6.812482e+06
# Los Lagos                                  6.805822e+06
# Magallanes y de la Antártica Chilena       6.746508e+06
# Ñuble                                      5.237524e+06
# Aysén del General Carlos Ibáñez del Campo  4.201783e+06
# La región con mayor promedio de presupuesto es la metropolitana
#                             PRESUPUESTO
# Nombre Región
# Metropolitana de Santiago  4.341656e+07

# %% [markdown]
# ## Pregunta 3

# %%
# Escriba su código aquí
df_pre_pob_comuna = pd.merge(poblacion, presupuesto[['CODIGO','PRESUPUESTO']], on="CODIGO")
df_pre_pob_comuna['PRESUPUESTO'].convert_dtypes()
df_pre_pob_comuna.PRESUPUESTO = pd.to_numeric(df_presupuesto_region.PRESUPUESTO, errors='coerce')

df_mayor_pob = df_pre_pob_comuna.sort_values(by='PRESUPUESTO', ascending=False)
df_mayor_pre = df_pre_pob_comuna.sort_values(by='POBLACIÓN', ascending=False)

print("Comunas con mayor presupuesto, de mayor a menor:")
display(df_mayor_pob.head(20))

print("Comunas con mayor población:")
display(df_mayor_pre.head(20))

print("A continuación veremos que comunas del top 20 de presupuesto están además en el top 20 de población:")
for i in range(0,20):
  for j in range(0,20):
    #display(df_mayor_pob.iloc[i]['MUNICIPIO'])          #Usado para ver las comparaciones por nombre de comuna
    #display(df_mayor_pre.iloc[j]['MUNICIPIO'])
    #print("")
    if df_mayor_pob.iloc[i]['MUNICIPIO'] == df_mayor_pre.iloc[j]['MUNICIPIO']:
      print(f"True para comuna {i+1}")
      break
print("")      
print("Podemos ver que solo hay 4 comunas que a pesar de tener un gran presupuesto, no cuentan dentro del top 20 de población")
print("Estas comunas son Providencia, Vitacura, Lo Barnechea, e Iquique")
print("")
print("De esta situación se puede comentar que hay una estrecha relación entre presupuesto y población por comuna, pero que aún así existe desigualdad.")
# Out:
# Comunas con mayor presupuesto, de mayor a menor:
#      CODIGO     MUNICIPIO  POBLACIÓN  PRESUPUESTO
# 269   13114    LAS CONDES     323309  339980450.0
# 256   13101      SANTIAGO     486838  163383547.0
# 278   13123   PROVIDENCIA     154446  125041538.0
# 274   13119         MAIPÚ     566664  119318265.0
# 7      2101   ANTOFAGASTA     410618  100635302.0
# 46     5109  VIÑA DEL MAR     357228  100482380.0
# 287   13132      VITACURA      94020   97000000.0
# 265   13110    LA FLORIDA     396781   95609849.0
# 270   13115  LO BARNECHEA     119240   92819385.0
# 279   13124      PUDAHUEL     248347   87884438.0
# 288   13201   PUENTE ALTO     629743   85384573.0
# 40     5101    VALPARAÍSO     313185   77718000.0
# 174    9101        TEMUCO     300618   66388232.0
# 275   13120         ÑUÑOA     240753   63443811.0
# 25     4101     LA SERENA     244170   59222000.0
# 0      1101       IQUIQUE     216514   59072234.0
# 26     4102      COQUIMBO     250947   56819394.0
# 277   13122     PEÑALOLÉN     262268   56733837.0
# 78     6101      RANCAGUA     261992   55996193.0
# 294   13401  SAN BERNARDO     329121   52127690.0
# Comunas con mayor población:
#      CODIGO     MUNICIPIO  POBLACIÓN  PRESUPUESTO
# 288   13201   PUENTE ALTO     629743   85384573.0
# 274   13119         MAIPÚ     566664  119318265.0
# 256   13101      SANTIAGO     486838  163383547.0
# 7      2101   ANTOFAGASTA     410618  100635302.0
# 265   13110    LA FLORIDA     396781   95609849.0
# 46     5109  VIÑA DEL MAR     357228  100482380.0
# 294   13401  SAN BERNARDO     329121   52127690.0
# 269   13114    LAS CONDES     323309  339980450.0
# 40     5101    VALPARAÍSO     313185   77718000.0
# 174    9101        TEMUCO     300618   66388232.0
# 206   10101  PUERTO MONTT     265863   52090583.0
# 277   13122     PEÑALOLÉN     262268   56733837.0
# 78     6101      RANCAGUA     261992   55996193.0
# 26     4102      COQUIMBO     250947   56819394.0
# 279   13124      PUDAHUEL     248347   87884438.0
# 25     4101     LA SERENA     244170   59222000.0
# 280   13125     QUILICURA     243112   46258275.0
# 320   15101         ARICA     242510   37808221.0
# 275   13120         ÑUÑOA     240753   63443811.0
# 141    8101    CONCEPCIÓN     237257   44704000.0
# A continuación veremos que comunas del top 20 de presupuesto están además en el top 20 de población:
# True para comuna 1
# True para comuna 2
# True para comuna 4
# True para comuna 5
# True para comuna 6
# True para comuna 8
# True para comuna 10
# True para comuna 11
# True para comuna 12
# True para comuna 13
# True para comuna 14
# True para comuna 15
# True para comuna 17
# True para comuna 18
# True para comuna 19
# True para comuna 20
#
# Podemos ver que solo hay 4 comunas que a pesar de tener un gran presupuesto, no cuentan dentro del top 20 de población
# Estas comunas son Providencia, Vitacura, Lo Barnechea, e Iquique
#
# De esta situación se puede comentar que hay una estrecha relación entre presupuesto y población por comuna, pero que aún así existe desigualdad.
